# %%
# !ls /workspace/results/temp/
# Out:
# all_verilog_srcs.txt		       make_project.tcl
# bitfile_qce_alveo.xclbin	       parent_model.onnx
# bnn_pynq.onnx			       qn_u250.xclbin
# dataflow_partition0_v0h2dcyi	       report
# df_model.onnx			       run_vitis_link.sh
# df_model_bitfile.onnx		       run_vitis_link_outside_container.sh
# df_model_fifos.onnx		       runme.log
# df_model_stitchedip.onnx	       vitisbuild.zip
# end2end_cnv_w1a1_export.onnx	       vivado_hls.log
# end2end_cnv_w1a1_import_and_tidy.onnx  xbutil_dump.txt
# end2end_cnv_w1a1_pre_post.onnx	       xml_bitfile_cnv.xml
# end2end_cnv_w1a1_preproc.onnx	       xml_bitfile_cnv_u50.xml
# end2end_quartznet_fifos.onnx	       xml_bitfile_qce_alveo.xml
# end2end_quartznet_stitched_ip.onnx     xml_bitfile_quartznet.xml

# %%
from finn.util.visualization import showInNetron

showInNetron("/workspace/results/syn_baseline/dataflow_partition0_81fmxkyy/df_model_fifos.onnx")
# Out:
# Serving '/workspace/results/syn_baseline/dataflow_partition0_81fmxkyy/df_model_fifos.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from finn.core.modelwrapper import ModelWrapper
from finn.transformation.fpgadataflow.insert_fifo import InsertFIFO
from finn.transformation.general import GiveUniqueNodeNames

model = ModelWrapper("/workspace/results/syn_baseline/dataflow_partition0_81fmxkyy/df_model_fifos.onnx")
model = model.transform(InsertFIFO(create_shallow_fifos=True))
model = model.transform(GiveUniqueNodeNames())
model.save("/tmp/shallow_fifo.onnx")
# Out:
# /workspace/finn/src/finn/transformation/fpgadataflow/insert_fifo.py:156: UserWarning: Overriding input FIFO depth to 32
#   warnings.warn("Overriding input FIFO depth to 32")
# /workspace/finn/src/finn/transformation/fpgadataflow/insert_fifo.py:202: UserWarning: Overriding output FIFO depth to 32
#   warnings.warn("Overriding output FIFO depth to 32")

# %%
from finn.util.visualization import showInNetron

showInNetron("/tmp/shallow_fifo.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving '/tmp/shallow_fifo.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from finn.custom_op.registry import getCustomOp

model = ModelWrapper("/tmp/shallow_fifo.onnx")

print_list = []
for n in model.graph.node:
    if n.op_type=="StreamingFIFO":
        name = n.name
        name_split = name.split("_")
        fifo_idx = int(name_split[1])
        if fifo_idx>=1 and fifo_idx<=37:
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=38 and fifo_idx<=74:
            if fifo_idx==38:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=75 and fifo_idx<=111:
            if fifo_idx==75:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=112 and fifo_idx<=148:
            if fifo_idx==112:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=149 and fifo_idx<=185:
            if fifo_idx==149:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=186 and fifo_idx<=222:
            if fifo_idx==186:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=223 and fifo_idx<=260:
            if fifo_idx==223:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            elif fifo_idx in [226, 233]:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "ultra", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=261 and fifo_idx<=297:
            if fifo_idx==261:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=298 and fifo_idx<=334:
            if fifo_idx==298:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=335 and fifo_idx<=371:
            if fifo_idx==335:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=372 and fifo_idx<=408:
            if fifo_idx==372:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=409 and fifo_idx<=445:
            if fifo_idx==409:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=446 and fifo_idx<=487:
            if fifo_idx==446:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            elif fifo_idx in [451, 455, 460, 462, 467, 469, 474, 476, 481, 483]:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "ultra", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=488 and fifo_idx<=529:
            if fifo_idx==488:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            elif fifo_idx in [493, 497, 502, 504, 509, 511, 516, 518, 523, 525]:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "ultra", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=530 and fifo_idx<=571:
            if fifo_idx==530:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fold==1:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},'
            elif fifo_idx in [535, 539, 544, 546, 551, 553, 558, 560, 565, 567]:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "ultra", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
        elif fifo_idx>=572 and fifo_idx<=580:
            if fifo_idx==572:
                print("-------------------------------------------------------")
            inst = getCustomOp(n)
            folded_shape = inst.get_nodeattr("folded_shape")
            total_depth = folded_shape[1]*folded_shape[3]
            fold = folded_shape[4]
            if fifo_idx in [576, 579]:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 4096, "ram_style" : "ultra", "impl_style" : "vivado"},'
            else:
                to_print = '"StreamingFIFO_'+str(fifo_idx)+'" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},'
            print_list.append(to_print)
            print("{}  {}  {}".format(fifo_idx,folded_shape, total_depth))
# Out:
# 1  [1, 128, 1, 256, 1]  32768
# 2  [1, 128, 1, 256, 1]  32768
# 3  [1, 128, 1, 256, 1]  32768
# 4  [1, 128, 1, 64, 4]  8192
# 5  [1, 160, 1, 256, 1]  40960
# 6  [1, 160, 1, 64, 4]  10240
# 7  [1, 128, 1, 64, 4]  8192
# 8  [1, 128, 1, 256, 1]  32768
# 9  [1, 128, 1, 2112, 4]  270336
# 10  [1, 128, 1, 64, 4]  8192
# 11  [1, 128, 1, 64, 4]  8192
# 12  [1, 128, 1, 256, 1]  32768
# 13  [1, 160, 1, 256, 1]  40960
# 14  [1, 160, 1, 64, 4]  10240
# 15  [1, 128, 1, 2112, 4]  270336
# 16  [1, 128, 1, 64, 4]  8192
# 17  [1, 128, 1, 64, 4]  8192
# 18  [1, 128, 1, 256, 1]  32768
# 19  [1, 160, 1, 256, 1]  40960
# 20  [1, 160, 1, 64, 4]  10240
# 21  [1, 128, 1, 2112, 4]  270336
# 22  [1, 128, 1, 64, 4]  8192
# 23  [1, 128, 1, 64, 4]  8192
# 24  [1, 128, 1, 256, 1]  32768
# 25  [1, 160, 1, 256, 1]  40960
# 26  [1, 160, 1, 64, 4]  10240
# 27  [1, 128, 1, 2112, 4]  270336
# 28  [1, 128, 1, 64, 4]  8192
# 29  [1, 128, 1, 64, 4]  8192
# 30  [1, 128, 1, 256, 1]  32768
# 31  [1, 160, 1, 256, 1]  40960
# ...

# %%
for el in print_list:
    print(el)
# Out:
# "StreamingFIFO_1" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},
# "StreamingFIFO_2" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},
# "StreamingFIFO_3" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},
# "StreamingFIFO_4" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},
# "StreamingFIFO_5" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},
# "StreamingFIFO_6" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},
# "StreamingFIFO_7" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},
# "StreamingFIFO_8" : {"depth" : 4096, "ram_style" : "block", "impl_style" : "vivado"},
# "StreamingFIFO_9" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},
# "StreamingFIFO_10" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},
# "StreamingFIFO_11" : {"depth" : 8192, "ram_style" : "ultra", "impl_style" : "vivado"},
# ...
