# %%
import numpy as np
from onnx import TensorProto, helper

from finn.custom_op.registry import getCustomOp
import finn.core.onnx_exec as oxe
import finn.custom_op.general.xnorpopcount as xp
from finn.analysis.fpgadataflow.hls_synth_res_estimation import hls_synth_res_estimation
from finn.core.datatype import DataType
from finn.core.modelwrapper import ModelWrapper
from finn.custom_op.general.multithreshold import multithreshold
from finn.transformation.fpgadataflow.prepare_ip import PrepareIP
from finn.transformation.fpgadataflow.prepare_cppsim import PrepareCppSim
from finn.transformation.fpgadataflow.compile_cppsim import CompileCppSim
from finn.transformation.fpgadataflow.hlssynth_ip import HLSSynthIP
from finn.transformation.fpgadataflow.set_exec_mode import SetExecMode
from finn.transformation.general import GiveUniqueNodeNames
from finn.transformation.fpgadataflow.prepare_rtlsim import PrepareRTLSim
from finn.util.basic import calculate_signed_dot_prod_range, gen_finn_dt_tensor
from finn.analysis.fpgadataflow.exp_cycles_per_layer import exp_cycles_per_layer


def make_single_fclayer_modelwrapper(W, pe, simd, wdt, idt, odt, T=None, tdt=None):
    mw = W.shape[0]
    mh = W.shape[1]
    assert mh % pe == 0
    assert mw % simd == 0

    # there are two ways to implement bipolar weights and inputs for
    # StreamingFC:
    # - specify their datatypes as such
    # - specify their datatypes as BINARY as use binaryXnorMode
    if wdt == DataType.BIPOLAR and idt == DataType.BIPOLAR:
        # we'll internally convert weights/inputs to binary and specify the
        # datatypes as such, and also set the binaryXnorMode attribute to 1
        export_wdt = DataType.BINARY
        export_idt = DataType.BINARY
        binary_xnor_mode = 1
    else:
        export_wdt = wdt
        export_idt = idt
        binary_xnor_mode = 0

    inp = helper.make_tensor_value_info("inp", TensorProto.FLOAT, [1, mw])
    outp = helper.make_tensor_value_info("outp", TensorProto.FLOAT, [1, mh])
    if T is not None:
        no_act = 0
        node_inp_list = ["inp", "weights", "thresh"]
        if odt == DataType.BIPOLAR:
            actval = 0
        else:
            actval = odt.min()
    else:
        # no thresholds
        node_inp_list = ["inp", "weights"]
        actval = 0
        no_act = 1
    FCLayer_node = helper.make_node(
        "StreamingFCLayer_Batch",
        node_inp_list,
        ["outp"],
        domain="finn.custom_op.fpgadataflow",
        backend="fpgadataflow",
        MW=mw,
        MH=mh,
        SIMD=simd,
        PE=pe,
        inputDataType=export_idt.name,
        weightDataType=export_wdt.name,
        outputDataType=odt.name,
        ActVal=actval,
        binaryXnorMode=binary_xnor_mode,
        noActivation=no_act,
    )
    graph = helper.make_graph(
        nodes=[FCLayer_node], name="fclayer_graph", inputs=[inp], outputs=[outp]
    )

    model = helper.make_model(graph, producer_name="fclayer-model")
    model = ModelWrapper(model)

    model.set_tensor_datatype("inp", idt)
    model.set_tensor_datatype("outp", odt)
    model.set_tensor_datatype("weights", wdt)
    if binary_xnor_mode:
        # convert bipolar to binary
        model.set_initializer("weights", (W + 1) / 2)
    else:
        model.set_initializer("weights", W)
    if T is not None:
        model.set_tensor_datatype("thresh", tdt)
        model.set_initializer("thresh", T)
    return model


def prepare_inputs(input_tensor, idt, wdt):
    if wdt == DataType.BIPOLAR and idt == DataType.BIPOLAR:
        # convert bipolar to binary
        return {"inp": (input_tensor + 1) / 2}
    else:
        return {"inp": input_tensor}


def test_fpgadataflow_fclayer_cppsim(mem_mode, idt, wdt, act, nf, sf, mw, mh):
    if nf == -1:
        nf = mh
    if sf == -1:
        sf = mw
    pe = mh // nf
    simd = mw // sf
    assert mh % pe == 0
    assert mw % sf == 0
    # generate weights
    W = gen_finn_dt_tensor(wdt, (mw, mh))
    # generate input data
    x = gen_finn_dt_tensor(idt, (1, mw))
    if act is None:
        # no activation, produce accumulators
        T = None
        tdt = None
        if wdt == DataType.BIPOLAR and idt == DataType.BIPOLAR:
            odt = DataType.UINT32
        else:
            odt = DataType.INT32
    else:
        odt = act
        (min, max) = calculate_signed_dot_prod_range(idt, wdt, mw)
        n_steps = act.get_num_possible_values() - 1
        T = np.random.randint(min, max - 1, (mh, n_steps)).astype(np.float32)
        # provide non-decreasing thresholds
        T = np.sort(T, axis=1)
        # generate thresholds for activation
        if wdt == DataType.BIPOLAR and idt == DataType.BIPOLAR:
            tdt = DataType.UINT32
            # bias thresholds to be positive
            T = np.ceil((T + mw) / 2)
            assert (T >= 0).all()
        else:
            tdt = DataType.INT32
    model = make_single_fclayer_modelwrapper(W, pe, simd, wdt, idt, odt, T, tdt)
    for node in model.graph.node:
        # lookup op_type in registry of CustomOps
        inst = getCustomOp(node)
        inst.set_nodeattr("mem_mode", mem_mode)
    model = model.transform(SetExecMode("cppsim"))
    model = model.transform(PrepareCppSim())
    model = model.transform(CompileCppSim())
    # prepare input data
    input_dict = prepare_inputs(x, idt, wdt)
    if wdt == DataType.BIPOLAR and idt == DataType.BIPOLAR:
        # convert inputs to binary and use xnorpopcountmatmul
        y = xp.xnorpopcountmatmul((x + 1) / 2, (W + 1) / 2)
    else:
        y = np.matmul(x, W)
    if T is not None:
        y = multithreshold(y, T)
        if act == DataType.BIPOLAR:
            # binary to bipolar
            y = 2 * y - 1
        else:
            # signed offset
            y += act.min()
    oshape = model.get_tensor_shape("outp")
    y_expected = y.reshape(oshape)
    # execute model
    y_produced = oxe.execute_onnx(model, input_dict)["outp"]

    y_produced = y_produced.reshape(y_expected.shape)

    assert (y_produced == y_expected).all(), "cppsim failed"


def test_fpgadataflow_fclayer_rtlsim(mem_mode, idt, wdt, act, nf, sf, mw, mh):
    if nf == -1:
        nf = mh
    if sf == -1:
        sf = mw
    pe = mh // nf
    simd = mw // sf
    assert mh % pe == 0
    assert mw % sf == 0
    # generate weights
    W = gen_finn_dt_tensor(wdt, (mw, mh))
    # generate input data
    x = gen_finn_dt_tensor(idt, (1, mw))
    if act is None:
        # no activation, produce accumulators
        T = None
        tdt = None
        if wdt == DataType.BIPOLAR and idt == DataType.BIPOLAR:
            odt = DataType.UINT32
        else:
            odt = DataType.INT32
    else:
        odt = act
        (min, max) = calculate_signed_dot_prod_range(idt, wdt, mw)
        n_steps = act.get_num_possible_values() - 1
        T = np.random.randint(min, max - 1, (mh, n_steps)).astype(np.float32)
        # provide non-decreasing thresholds
        T = np.sort(T, axis=1)
        # generate thresholds for activation
        if wdt == DataType.BIPOLAR and idt == DataType.BIPOLAR:
            tdt = DataType.UINT32
            # bias thresholds to be positive
            T = np.ceil((T + mw) / 2)
            assert (T >= 0).all()
        else:
            tdt = DataType.INT32
    model = make_single_fclayer_modelwrapper(W, pe, simd, wdt, idt, odt, T, tdt)
    for node in model.graph.node:
        # lookup op_type in registry of CustomOps
        inst = getCustomOp(node)
        inst.set_nodeattr("mem_mode", mem_mode)

    # prepare input data
    input_dict = prepare_inputs(x, idt, wdt)
    if wdt == DataType.BIPOLAR and idt == DataType.BIPOLAR:
        # convert inputs to binary and use xnorpopcountmatmul
        y = xp.xnorpopcountmatmul((x + 1) / 2, (W + 1) / 2)
    else:
        y = np.matmul(x, W)
    if T is not None:
        y = multithreshold(y, T)
        if act == DataType.BIPOLAR:
            # binary to bipolar
            y = 2 * y - 1
        else:
            # signed offset
            y += act.min()
    oshape = model.get_tensor_shape("outp")
    y_expected = y.reshape(oshape)
    # TODO split up into several dependent tests -- need to check how this
    # works for parametrized tests...
    model = model.transform(SetExecMode("rtlsim"))
    model = model.transform(GiveUniqueNodeNames())
    model = model.transform(PrepareIP("xc7z020clg400-1", 5))
    model = model.transform(HLSSynthIP())
    model = model.transform(PrepareRTLSim())
    y_produced = oxe.execute_onnx(model, input_dict)["outp"]
    assert (y_produced.reshape(y_expected.shape) == y_expected).all(), "rtlsim failed"

    hls_synt_res_est = model.analysis(hls_synth_res_estimation)
    assert "StreamingFCLayer_Batch_0" in hls_synt_res_est

    node = model.get_nodes_by_op_type("StreamingFCLayer_Batch")[0]
    inst = getCustomOp(node)
    cycles_rtlsim = inst.get_nodeattr("cycles_rtlsim")
    exp_cycles_dict = model.analysis(exp_cycles_per_layer)
    exp_cycles = exp_cycles_dict[node.name]
    assert np.isclose(exp_cycles, cycles_rtlsim, atol=15)
    assert exp_cycles != 0


def test_fpgadataflow_fclayer_large_depth_decoupled_mode_rtlsim(
    mem_mode, idt, wdt, act, nf, sf, mw, mh
):
    if nf == -1:
        nf = mh
    if sf == -1:
        sf = mw
    pe = mh // nf
    simd = mw // sf
    assert mh % pe == 0
    assert mw % sf == 0
    # generate weights
    W = gen_finn_dt_tensor(wdt, (mw, mh))
    # generate input data
    x = gen_finn_dt_tensor(idt, (1, mw))
    if act is None:
        # no activation, produce accumulators
        T = None
        tdt = None
        if wdt == DataType.BIPOLAR and idt == DataType.BIPOLAR:
            odt = DataType.UINT32
        else:
            odt = DataType.INT32
    else:
        odt = act
        (min, max) = calculate_signed_dot_prod_range(idt, wdt, mw)
        n_steps = act.get_num_possible_values() - 1
        T = np.random.randint(min, max - 1, (mh, n_steps)).astype(np.float32)
        # provide non-decreasing thresholds
        T = np.sort(T, axis=1)
        # generate thresholds for activation
        if wdt == DataType.BIPOLAR and idt == DataType.BIPOLAR:
            tdt = DataType.UINT32
            # bias thresholds to be positive
            T = np.ceil((T + mw) / 2)
            assert (T >= 0).all()
        else:
            tdt = DataType.INT32
    model = make_single_fclayer_modelwrapper(W, pe, simd, wdt, idt, odt, T, tdt)
    for node in model.graph.node:
        # lookup op_type in registry of CustomOps
        inst = getCustomOp(node)
        inst.set_nodeattr("mem_mode", mem_mode)

    # prepare input data
    input_dict = prepare_inputs(x, idt, wdt)
    if wdt == DataType.BIPOLAR and idt == DataType.BIPOLAR:
        # convert inputs to binary and use xnorpopcountmatmul
        y = xp.xnorpopcountmatmul((x + 1) / 2, (W + 1) / 2)
    else:
        y = np.matmul(x, W)
    if T is not None:
        y = multithreshold(y, T)
        if act == DataType.BIPOLAR:
            # binary to bipolar
            y = 2 * y - 1
        else:
            # signed offset
            y += act.min()
    oshape = model.get_tensor_shape("outp")
    y_expected = y.reshape(oshape)
    # TODO split up into several dependent tests -- need to check how this
    # works for parametrized tests...
    model = model.transform(SetExecMode("rtlsim"))
    model = model.transform(GiveUniqueNodeNames())
    model = model.transform(PrepareIP("xc7z020clg400-1", 5))
    model = model.transform(HLSSynthIP())
    model = model.transform(PrepareRTLSim())
    y_produced = oxe.execute_onnx(model, input_dict)["outp"]
    assert (y_produced.reshape(y_expected.shape) == y_expected).all(), "rtlsim failed"

    hls_synt_res_est = model.analysis(hls_synth_res_estimation)
    assert "StreamingFCLayer_Batch_0" in hls_synt_res_est

    node = model.get_nodes_by_op_type("StreamingFCLayer_Batch")[0]
    inst = getCustomOp(node)
    cycles_rtlsim = inst.get_nodeattr("cycles_rtlsim")
    exp_cycles_dict = model.analysis(exp_cycles_per_layer)
    exp_cycles = exp_cycles_dict[node.name]
    assert np.isclose(exp_cycles, cycles_rtlsim, atol=15)
    assert exp_cycles != 0

# %%
# mem_mode: const or decoupled
#@pytest.mark.parametrize("mem_mode", ["const", "decoupled", "external"])
mem_mode = 'decoupled'
# activation: None or DataType
#@pytest.mark.parametrize("act", [None, DataType.BIPOLAR, DataType.INT4])
act = DataType.UINT8
# weight datatype
#@pytest.mark.parametrize("wdt", [DataType.BIPOLAR, DataType.INT4])
wdt = DataType.INT8
# input datatype
#@pytest.mark.parametrize("idt", [DataType.BIPOLAR, DataType.INT4])
idt = DataType.INT8
# neuron folding, -1 is maximum possible
#@pytest.mark.parametrize("nf", [-1, 2, 1])
nf = 32
# synapse folding, -1 is maximum possible
#@pytest.mark.parametrize("sf", [-1, 2, 1])
sf = 64
# HLS matrix width (input features)
#@pytest.mark.parametrize("mw", [16])
mw = 64
# HLS matrix height (output features)
#@pytest.mark.parametrize("mh", [16])
mh = 256
test_fpgadataflow_fclayer_cppsim(mem_mode, idt, wdt, act, nf, sf, mw, mh)

# %%
# mem_mode: const or decoupled
#@pytest.mark.parametrize("mem_mode", ["const", "decoupled", "external"])
mem_mode = 'decoupled'
# activation: None or DataType
#@pytest.mark.parametrize("act", [None, DataType.BIPOLAR, DataType.INT4])
act = DataType.UINT8
# weight datatype
#@pytest.mark.parametrize("wdt", [DataType.BIPOLAR, DataType.INT4])
wdt = DataType.INT8
# input datatype
#@pytest.mark.parametrize("idt", [DataType.BIPOLAR, DataType.INT4])
idt = DataType.INT8
# neuron folding, -1 is maximum possible
#@pytest.mark.parametrize("nf", [-1, 2, 1])
nf = 32
# synapse folding, -1 is maximum possible
#@pytest.mark.parametrize("sf", [-1, 2, 1])
sf = 64
# HLS matrix width (input features)
#@pytest.mark.parametrize("mw", [16])
mw = 64
# HLS matrix height (output features)
#@pytest.mark.parametrize("mh", [16])
mh = 256
test_fpgadataflow_fclayer_rtlsim(mem_mode, idt, wdt, act, nf, sf, mw, mh)
# Out:
# %Warning-STMTDLY: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:22252: Unsupported: Ignoring delay on this delayed statement.
# %Warning-STMTDLY: Use "/* verilator lint_off STMTDLY */" and lint_on around source to disable this message.
# %Warning-STMTDLY: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:22253: Unsupported: Ignoring delay on this delayed statement.
# %Warning-STMTDLY: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:22254: Unsupported: Ignoring delay on this delayed statement.
# %Warning-STMTDLY: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:22255: Unsupported: Ignoring delay on this delayed statement.
# %Warning-STMTDLY: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:22256: Unsupported: Ignoring delay on this delayed statement.
# %Warning-STMTDLY: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:22257: Unsupported: Ignoring delay on this delayed statement.
# %Warning-STMTDLY: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:22258: Unsupported: Ignoring delay on this delayed statement.
# %Warning-STMTDLY: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:22259: Unsupported: Ignoring delay on this delayed statement.
# %Warning-STMTDLY: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:22260: Unsupported: Ignoring delay on this delayed statement.
# %Warning-STMTDLY: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:22261: Unsupported: Ignoring delay on this delayed statement.
# %Warning-STMTDLY: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:22262: Unsupported: Ignoring delay on this delayed statement.
# %Warning-STMTDLY: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0.v:78: Unsupported: Ignoring delay on this delayed statement.
# %Warning-STMTDLY: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0.v:79: Unsupported: Ignoring delay on this delayed statement.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:67606: Operator ASSIGN expects 3 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:71739: Operator ASSIGNW expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75839: Operator ASSIGNW expects 8 bits on the Assign RHS, but Assign RHS's VARREF 'sext_ln215_1_fu_32077_p1' generates 16 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75841: Operator ASSIGNW expects 8 bits on the Assign RHS, but Assign RHS's VARREF 'sext_ln215_1_fu_32077_p1' generates 16 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75843: Operator ASSIGNW expects 8 bits on the Assign RHS, but Assign RHS's VARREF 'sext_ln215_1_fu_32077_p1' generates 16 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75845: Operator ASSIGNW expects 8 bits on the Assign RHS, but Assign RHS's VARREF 'sext_ln215_1_fu_32077_p1' generates 16 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75847: Operator ASSIGNW expects 8 bits on the Assign RHS, but Assign RHS's VARREF 'sext_ln215_1_fu_32077_p1' generates 16 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75849: Operator ASSIGNW expects 8 bits on the Assign RHS, but Assign RHS's VARREF 'sext_ln215_1_fu_32077_p1' generates 16 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75851: Operator ASSIGNW expects 8 bits on the Assign RHS, but Assign RHS's VARREF 'sext_ln215_1_fu_32077_p1' generates 16 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75853: Operator ASSIGNW expects 8 bits on the Assign RHS, but Assign RHS's VARREF 'sext_ln215_1_fu_32077_p1' generates 16 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75877: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75879: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75881: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75883: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75885: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75887: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75889: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75891: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75893: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75895: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75897: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75899: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75901: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75903: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75905: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75907: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75909: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75911: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75913: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75915: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75917: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75919: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75921: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75923: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75925: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75927: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75929: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75931: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75933: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75935: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75937: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75939: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75941: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75943: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75945: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75947: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75949: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75951: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75953: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75955: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75957: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75959: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75961: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75963: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75965: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75967: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75969: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75971: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75973: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75975: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75977: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75979: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75981: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75983: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75985: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75987: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75989: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75991: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75993: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75995: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75997: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:75999: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76001: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76003: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76005: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76007: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76009: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76011: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76013: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76015: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76017: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76019: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76021: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76023: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76025: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76027: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76029: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76031: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76033: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76035: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76037: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76039: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76041: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76043: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76045: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76047: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76049: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76051: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76053: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76055: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76057: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76059: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76061: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76063: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76065: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76067: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76069: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76071: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76073: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76075: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76077: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76079: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76081: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76083: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76085: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76087: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76089: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76091: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76093: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76095: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76097: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 21 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76099: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76101: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76103: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76105: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76107: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76109: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76111: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76113: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76115: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76117: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76119: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76121: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76123: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76125: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76127: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76129: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76131: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76133: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76135: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76137: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76139: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76141: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 20 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76143: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76145: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76147: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76149: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76151: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76153: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76155: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76157: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76159: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76161: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:76163: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's SIGNED generates 19 bits.
# ...
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96419: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_993_reg_116563' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96421: Operator ASSIGNW expects 4 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_994_fu_80870_p2' generates 3 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96423: Operator ASSIGNW expects 5 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_995_reg_119673' generates 4 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96425: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_100_reg_114383' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96427: Operator ASSIGNW expects 6 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_996_fu_86666_p2' generates 5 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96429: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_997_reg_116568' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96431: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_998_reg_116573' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96433: Operator ASSIGNW expects 4 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_999_fu_80892_p2' generates 3 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96435: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1000_reg_116578' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96437: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1001_reg_116583' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96439: Operator ASSIGNW expects 4 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1002_fu_80908_p2' generates 3 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96441: Operator ASSIGNW expects 5 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1003_reg_119678' generates 4 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96443: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1004_reg_116588' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96445: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1005_reg_116593' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96447: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_101_reg_114388' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96449: Operator ASSIGNW expects 4 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1006_fu_80930_p2' generates 3 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96451: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1007_reg_116598' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96453: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1008_reg_116603' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96455: Operator ASSIGNW expects 4 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1009_fu_80946_p2' generates 3 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96457: Operator ASSIGNW expects 5 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1010_reg_119683' generates 4 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96459: Operator ASSIGNW expects 6 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1011_fu_86682_p2' generates 5 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96461: Operator ASSIGNW expects 7 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1012_reg_120483' generates 6 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96463: Operator ASSIGNW expects 8 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1013_reg_120723_pp0_iter8_reg' generates 7 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96465: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'xor_ln899_1274_fu_59473_p2' generates 1 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96467: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1017_fu_59489_p2' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96469: Operator ASSIGNW expects 4 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_102_fu_76763_p2' generates 3 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96471: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1018_fu_59499_p2' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96473: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1019_fu_59509_p2' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96475: Operator ASSIGNW expects 4 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1021_reg_116608' generates 3 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96477: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1022_fu_59531_p2' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96479: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1023_fu_59541_p2' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96481: Operator ASSIGNW expects 4 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1024_reg_116613' generates 3 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96483: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1025_fu_59557_p2' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96485: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1026_fu_59567_p2' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96487: Operator ASSIGNW expects 4 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1027_reg_116618' generates 3 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96489: Operator ASSIGNW expects 5 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_1029_reg_119688' generates 4 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96491: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_103_reg_114393' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96493: Operator ASSIGNW expects 3 bits on the Assign RHS, but Assign RHS's VARREF 'add_ln700_10_fu_38203_p2' generates 2 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_Matrix_Vector_Activa.v:96495: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'xor_ln899_254_fu_38109_p2' generates 1 bits.
# %Warning-WIDTH: /tmp/finn_dev_mirza/code_gen_ipgen_StreamingFCLayer_Batch_0_fnhmm5o5/project_StreamingFCLayer_Batch_0/sol1/impl/verilog//StreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0.v:217: Operator ASSIGN expects 4 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
# make: Entering directory '/tmp/finn_dev_mirza/pyverilator_StreamingFCLayer_Batch_0_a07qoy49'
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVL_PRINTF=printf -DVM_TRACE=1 -DVM_COVERAGE=0 -Wno-char-subscripts -Wno-parentheses-equality -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable     -fPIC --std=c++11   -c -o pyverilator_wrapper.o /tmp/finn_dev_mirza/pyverilator_StreamingFCLayer_Batch_0_a07qoy49/pyverilator_wrapper.cpp
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVL_PRINTF=printf -DVM_TRACE=1 -DVM_COVERAGE=0 -Wno-char-subscripts -Wno-parentheses-equality -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable     -fPIC --std=c++11   -c -o verilated.o /usr/share/verilator/include/verilated.cpp
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVL_PRINTF=printf -DVM_TRACE=1 -DVM_COVERAGE=0 -Wno-char-subscripts -Wno-parentheses-equality -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable     -fPIC --std=c++11   -c -o verilated_vcd_c.o /usr/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0.cpp > VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__ALLcls.cpp
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVL_PRINTF=printf -DVM_TRACE=1 -DVM_COVERAGE=0 -Wno-char-subscripts -Wno-parentheses-equality -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable     -fPIC --std=c++11   -c -o VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__ALLcls.o VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__ALLcls.cpp
# /usr/bin/perl /usr/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__Trace.cpp VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__Syms.cpp VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__Trace__Slow.cpp > VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__ALLsup.cpp
# g++  -I.  -MMD -I/usr/share/verilator/include -I/usr/share/verilator/include/vltstd -DVL_PRINTF=printf -DVM_TRACE=1 -DVM_COVERAGE=0 -Wno-char-subscripts -Wno-parentheses-equality -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable     -fPIC --std=c++11   -c -o VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__ALLsup.o VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__ALLsup.cpp
#       Archiving VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__ALL.a ...
# ar r VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__ALL.a VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__ALLcls.o VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__ALLsup.o
# ranlib VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__ALL.a
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__ALL.a    -o VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0 -lm -lstdc++  2>&1 | c++filt
# make: Leaving directory '/tmp/finn_dev_mirza/pyverilator_StreamingFCLayer_Batch_0_a07qoy49'
# ar: creating VStreamingFCLayer_Batch_0_StreamingFCLayer_Batch_0__ALL.a
